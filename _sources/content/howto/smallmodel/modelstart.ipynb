# %% [markdown]
# # Create a small model from scratch and save it

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
from  modelmacrograb import GrabMacroModel
from modelclass import model
model.widescreen()
# Out:
#         <style>
#             div#notebook-container    { width: 95%; }
#             div#menubar-container     { width: 65%; }
#             div#maintoolbar-container { width: 99%; }
#         </style>

# %%
import modeljupytermagic  # to activate %%dataframe

# %% [markdown]
# ## Load the  national account data
# Using a jupyter magic command (something starting with %%) defined in modeljupytermagic

# %%
# %%dataframe smalldata start=2011
# Y CPV I G X M YDISC
# 2011 1562682. 1320302. 373938.8 131272.0 121715.0 444232.2 59686.22
# 2012 1632040. 1360376. 381170.2 128860.1 146292.9 457745.7 73087.14
# 2013 1689572. 1396402. 414556.8 124254.9 165234.6 522447.7 111572.0
# 2014 1791141. 1438904. 466473.0 138532.7 194705.5 632207.9 184733.1
# 2015 1862357. 1476067. 536416.7 154466.9 199214.9 692794.8 188986.9
# 2016 1870424. 1537410. 570679.5 135990.5 164738.9 714625.6 176230.0
# 2017 2038337. 1549515. 702407.5 165119.3 179327.0 916469.9 358437.5
# 2018 2193706. 1645118. 785371.4 168506.8 193124.7 1090956. 492542.0
# 2019 2339741. 1737872. 874480.5 180872.4 203830.6 1154398. 497084.1
# 2020 2295808. 1802824. 843961.1 192010.8 171282.5 978064.9 263794.1
# 2021 2327410. 1846635. 866899.3 211728.7 140302.8 1009072. 270916.5
# 2022 2402827. 1914157. 941428.0 240255.2 152623.9 1127119. 281482.2
# 2023 2536741. 2007600. 1060909. 252761.7 179968.7 1260336. 295838.0
# 2024 2715810. 2151422. 1205927. 278364.4 199108.6 1414850. 295837.8
# 2025 2924763. 2300322. 1359892. 307746.9 220190.6 1559226. 295837.8
# 2026 3140827. 2444181. 1512696. 337450.3 242638.9 1691977. 295837.8
# 2027 3335992. 2552411. 1652032. 363373.5 266225.5 1793888. 295837.8
# 2028 3528125. 2635657. 1787782. 388431.1 290729.5 1870312. 295837.8
# 2029 3729062. 2714120. 1927845. 414569.4 316021.6 1939332. 295837.8
# 2030 3945452. 2802550. 2076752. 441658.4 342117.3 2013464. 295837.8

# %% [markdown]
# ### Now we got a pandas dataframe with the values

# %%
smalldata
# Out:
#                Y        CPV          I         G         X          M  \
# index
# 2011   1562682.0  1320302.0   373938.8  131272.0  121715.0   444232.2
# 2012   1632040.0  1360376.0   381170.2  128860.1  146292.9   457745.7
# 2013   1689572.0  1396402.0   414556.8  124254.9  165234.6   522447.7
# 2014   1791141.0  1438904.0   466473.0  138532.7  194705.5   632207.9
# 2015   1862357.0  1476067.0   536416.7  154466.9  199214.9   692794.8
# 2016   1870424.0  1537410.0   570679.5  135990.5  164738.9   714625.6
# 2017   2038337.0  1549515.0   702407.5  165119.3  179327.0   916469.9
# 2018   2193706.0  1645118.0   785371.4  168506.8  193124.7  1090956.0
# 2019   2339741.0  1737872.0   874480.5  180872.4  203830.6  1154398.0
# 2020   2295808.0  1802824.0   843961.1  192010.8  171282.5   978064.9
# 2021   2327410.0  1846635.0   866899.3  211728.7  140302.8  1009072.0
# 2022   2402827.0  1914157.0   941428.0  240255.2  152623.9  1127119.0
# 2023   2536741.0  2007600.0  1060909.0  252761.7  179968.7  1260336.0
# 2024   2715810.0  2151422.0  1205927.0  278364.4  199108.6  1414850.0
# 2025   2924763.0  2300322.0  1359892.0  307746.9  220190.6  1559226.0
# 2026   3140827.0  2444181.0  1512696.0  337450.3  242638.9  1691977.0
# 2027   3335992.0  2552411.0  1652032.0  363373.5  266225.5  1793888.0
# 2028   3528125.0  2635657.0  1787782.0  388431.1  290729.5  1870312.0
# 2029   3729062.0  2714120.0  1927845.0  414569.4  316021.6  1939332.0
# 2030   3945452.0  2802550.0  2076752.0  441658.4  342117.3  2013464.0
#
#            YDISC
# index
# 2011    59686.22
# 2012    73087.14
# 2013   111572.00
# 2014   184733.10
# 2015   188986.90
# 2016   176230.00
# 2017   358437.50
# 2018   492542.00
# 2019   497084.10
# 2020   263794.10
# 2021   270916.50
# 2022   281482.20
# 2023   295838.00
# 2024   295837.80
# 2025   295837.80
# 2026   295837.80
# 2027   295837.80
# 2028   295837.80
# 2029   295837.80
# 2030   295837.80

# %% [markdown]
# ## Specify  a (small demo) model

# %% [markdown]
# Consumption
# Lets make consumption a function of GDP (a proxy for incomes) and just to be fancy we will do it an error correction format.
#
# **Long run equation**
#
# $ CPV_t= \alpha + \beta * Y_t +\eta_t $
#
# ECM
#
# $ \Delta cpv_t = - \gamma *(cpv_{t-1}- y_{t-1} - \beta_2 ) + \Delta y_t $ where lowercase variables preprsent the logarithm of the original variable
#
#  dlog(cpv)= -gamma_cpv*(log(cpv(-1))-log(y(-1)) - beta_cpv)+beta2_cpv*dlog(y)
#
#  dlog(g)=-gamma_g*(log(g(-1))-log(y(-1)) - beta_g)+beta2_g*dlog(y)
#
#
#  dlog(i)=-gamma_i*(log(i(-1))-log(y(-1)-g(-1)) - beta_i)+beta2_i*dlog(y)
#
#  dlog(m)=-gamma_m*(log(m(-1))-log(gde(-1)) - beta_m)+beta2_m*dlog(gde)
#
#  y=cpv+i+g+x-m+ydisc
#
#  gde=cpv+i+g

# %%
smallmodel = '''
<exo z> dlog(cpv)= -c2_cpv*(log(cpv(-1))-log(y(-1)) -        c1_cpv)+c3_cpv*dlog(y)

<exo z> dlog(g)  = -c2_g*  (log(g(-1))-  log(y(-1)) -        c1_g)  +c3_g*dlog(y)

<exo z> dlog(i)  = -c2_i*  (log(i(-1))-  log(y(-1)-g(-1)) - c1_i)   +c3_i*dlog(y) 
 
<exo z> dlog(m) =  -c2_m*  (log(m(-1))-   log(gde(-1))    - c1_m)   +c3_m*dlog(gde)
 
<ident> y=cpv+i+g+x-m+ydisc
 
<ident> gde=cpv+i+g

'''

# %% [markdown]
# ## Convert the specification to modelflow
# Here ```GrabMacroModel``` is used to process the model specification. It has been designed to process this type of models and can handle:
# - Introducing add_factors
# - Normalize equations
# - Make equations fixable
# - Generate equations for fitted values
# - Create model to calculate add factors
# - Create model to calculate fitted values
# - Create model to calculate identities
#
# In the next cell it is shown how each equation flows trough several phases.

# %%
thismodel = GrabMacroModel(smallmodel,modelname = 'Small demo model',make_fitted = True, debug = True)
# Out:
# Frml name:<EXO Z>
# Endo_var        : CPV
# Original        :  DLOG(CPV)= -C2_CPV*(LOG(CPV(-1))-LOG(Y(-1)) -        C1_CPV)+C3_CPV*DLOG(Y)
# Preprocessed    : ((LOG(CPV))-(LOG(CPV(-1))))=-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1))))
# Normalized      : CPV = (CPV(-1)*EXP(CPV_A+ (-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1))))) )) * (1-CPV_D)+ CPV_X*CPV_D
# Calc_add_factor : CPV_A = - ((-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1)))))) +LOG(CPV)-LOG(CPV(-1))
# Fitted          : CPV_FITTED = CPV(-1)*EXP( (-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1))))) )
#
# Frml name:<EXO Z>
# Endo_var        : G
# Original        :  DLOG(G)  = -C2_G*  (LOG(G(-1))-  LOG(Y(-1)) -        C1_G)  +C3_G*DLOG(Y)
# Preprocessed    : ((LOG(G))-(LOG(G(-1))))=-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1))))
# Normalized      : G = (G(-1)*EXP(G_A+ (-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1))))) )) * (1-G_D)+ G_X*G_D
# Calc_add_factor : G_A = - ((-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1)))))) +LOG(G)-LOG(G(-1))
# Fitted          : G_FITTED = G(-1)*EXP( (-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1))))) )
#
# Frml name:<EXO Z>
# Endo_var        : I
# Original        :  DLOG(I)  = -C2_I*  (LOG(I(-1))-  LOG(Y(-1)-G(-1)) - C1_I)   +C3_I*DLOG(Y)
# Preprocessed    : ((LOG(I))-(LOG(I(-1))))=-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1))))
# Normalized      : I = (I(-1)*EXP(I_A+ (-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1))))) )) * (1-I_D)+ I_X*I_D
# Calc_add_factor : I_A = - ((-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1)))))) +LOG(I)-LOG(I(-1))
# Fitted          : I_FITTED = I(-1)*EXP( (-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1))))) )
#
# Frml name:<EXO Z>
# Endo_var        : M
# Original        :  DLOG(M) =  -C2_M*  (LOG(M(-1))-   LOG(GDE(-1))    - C1_M)   +C3_M*DLOG(GDE)
# Preprocessed    : ((LOG(M))-(LOG(M(-1))))=-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1))))
# Normalized      : M = (M(-1)*EXP(M_A+ (-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1))))) )) * (1-M_D)+ M_X*M_D
# Calc_add_factor : M_A = - ((-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1)))))) +LOG(M)-LOG(M(-1))
# Fitted          : M_FITTED = M(-1)*EXP( (-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1))))) )
#
# Frml name:<IDENT>
# Endo_var        : Y
# Original        :  Y=CPV+I+G+X-M+YDISC
# Preprocessed    : Y=CPV+I+G+X-M+YDISC
# Normalized      : Y = CPV+I+G+X-M+YDISC
#
# Frml name:<IDENT>
# Endo_var        : GDE
# Original        :  GDE=CPV+I+G
# Preprocessed    : GDE=CPV+I+G
# Normalized      : GDE = CPV+I+G

# %% [markdown]
# ## Get the model
# As a convention **m** is used as prefix for model objects.
#
# So the model is called ```msmallmodel```

# %%
msmallmodel = thismodel.mmodel

# %% [markdown]
# ### Inject some variable descriptions.
# A Python dictionary is used for storing variable descriptions.

# %%
descriptions = {
    'CPV'   : 'Private Consumption',
    'Y'     : 'GDP' ,
    'G'     : 'Government' ,
    'I'     : 'Investment',
    'GDE'   : 'Gross Domestic Expenditure',
    'X'     : 'Export',
    'M'     : 'Import',
    'YDISC' :  'Discrepance',
}
msmallmodel.set_var_description(msmallmodel.enrich_var_description(descriptions))

# %% [markdown]
# ### The model equations
# Each equation has the form:
# >FRML \<[options]...> \<left hand variable> = \<right hand side expression>$
#
# Equations with the option ```CALC_ADD_FACTOR``` specifies a separate model which can be used to calculate the add factors
# which makes left hand side equals to the right hand side (without any fixing)
#
# So there are actually specified two models.

# %%
print(msmallmodel.equations)
# Out:
# FRML <EXO Z> CPV = (CPV(-1)*EXP(CPV_A+ (-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1))))) )) * (1-CPV_D)+ CPV_X*CPV_D $
# FRML <EXO Z> G = (G(-1)*EXP(G_A+ (-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1))))) )) * (1-G_D)+ G_X*G_D $
# FRML <EXO Z> I = (I(-1)*EXP(I_A+ (-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1))))) )) * (1-I_D)+ I_X*I_D $
# FRML <EXO Z> M = (M(-1)*EXP(M_A+ (-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1))))) )) * (1-M_D)+ M_X*M_D $
# FRML <IDENT> Y = CPV+I+G+X-M+YDISC$
# FRML <IDENT> GDE = CPV+I+G$
# FRML <FIT> CPV_FITTED = CPV(-1)*EXP( (-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1))))) )$
# FRML <FIT> G_FITTED = G(-1)*EXP( (-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1))))) )$
# FRML <FIT> I_FITTED = I(-1)*EXP( (-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1))))) )$
# FRML <FIT> M_FITTED = M(-1)*EXP( (-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1))))) )$
# FRML <CALC_ADD_FACTOR> CPV_A = - ((-C2_CPV*(LOG(CPV(-1))-LOG(Y(-1))-C1_CPV)+C3_CPV*((LOG(Y))-(LOG(Y(-1)))))) +LOG(CPV)-LOG(CPV(-1))$
# FRML <CALC_ADD_FACTOR> G_A = - ((-C2_G*(LOG(G(-1))-LOG(Y(-1))-C1_G)+C3_G*((LOG(Y))-(LOG(Y(-1)))))) +LOG(G)-LOG(G(-1))$
# FRML <CALC_ADD_FACTOR> I_A = - ((-C2_I*(LOG(I(-1))-LOG(Y(-1)-G(-1))-C1_I)+C3_I*((LOG(Y))-(LOG(Y(-1)))))) +LOG(I)-LOG(I(-1))$
# FRML <CALC_ADD_FACTOR> M_A = - ((-C2_M*(LOG(M(-1))-LOG(GDE(-1))-C1_M)+C3_M*((LOG(GDE))-(LOG(GDE(-1)))))) +LOG(M)-LOG(M(-1))$

# %% [markdown]
# ### The model structure can be drawn
# Notice that mouseover shows additional information

# %%
msmallmodel.drawmodel(size = (10,10))

# %% [markdown]
# ### Only the endogenous variables

# %%
msmallmodel.drawendo()

# %% [markdown]
# ### The adjacendy matrix for the endogenous variables.

# %%
msmallmodel.plotadjacency();

# %%
msmallmodel.endogene
# Out:
# {'CPV',
#  'CPV_FITTED',
#  'G',
#  'GDE',
#  'G_FITTED',
#  'I',
#  'I_FITTED',
#  'M',
#  'M_FITTED',
#  'Y'}

# %%
msmallmodel.exogene
# Out:
# {'C1_CPV',
#  'C1_G',
#  'C1_I',
#  'C1_M',
#  'C2_CPV',
#  'C2_G',
#  'C2_I',
#  'C2_M',
#  'C3_CPV',
#  'C3_G',
#  'C3_I',
#  'C3_M',
#  'CPV_A',
#  'CPV_D',
#  'CPV_X',
#  'G_A',
#  'G_D',
#  'G_X',
#  'I_A',
#  'I_D',
#  'I_X',
#  'M_A',
#  'M_D',
#  'M_X',
#  'X',
#  'YDISC'}

# %% [markdown]
# ## The Dataframe has to be enriched:
#
# - The the parameter values
# - Variables mentioned in the model, but not present in the dataframe
# - Calculated variables from the model has to be calculated
# - Add factors ensuring that the solution match the data has to be calculated.

# %% [markdown]
# ### The parameter values
# Modelflow is **not an estimation tool**. So we have to provide the estimated parameters. <br>
# This can be done in several way:
#  - The parameters can be input into the equations. This can be automated.
#  - The parameters can be broadcast into a dataframe. Which is what we will do here.
#
#  For this purpose a "magic" jupyter command will be used. It will create a dataframe with the right values:
#
# **Modelflow don't have a special datatype for parameters** so we just repeat the same value for all years

# %%
# %%dataframe parameters   periods=20 start=2011 melt t
#
#       c2      c1      c3
# cpv   0.38 -0.11 0.02946
# g     0.3 -2.5974  1.332
# i     0.3  -2.59 1.332
# m     0.37  -1.57 5.0929

# %%
baseline_first  = pd.concat([smalldata,parameters_melted],axis=1)
baseline_first  = msmallmodel.insertModelVar(baseline_first)
baseline_first.head().T
# Out:
# index               2011          2012          2013          2014  \
# Y           1.562682e+06  1.632040e+06  1.689572e+06  1.791141e+06
# CPV         1.320302e+06  1.360376e+06  1.396402e+06  1.438904e+06
# I           3.739388e+05  3.811702e+05  4.145568e+05  4.664730e+05
# G           1.312720e+05  1.288601e+05  1.242549e+05  1.385327e+05
# X           1.217150e+05  1.462929e+05  1.652346e+05  1.947055e+05
# M           4.442322e+05  4.577457e+05  5.224477e+05  6.322079e+05
# YDISC       5.968622e+04  7.308714e+04  1.115720e+05  1.847331e+05
# C2_CPV      3.800000e-01  3.800000e-01  3.800000e-01  3.800000e-01
# C1_CPV     -1.100000e-01 -1.100000e-01 -1.100000e-01 -1.100000e-01
# C3_CPV      2.946000e-02  2.946000e-02  2.946000e-02  2.946000e-02
# C2_G        3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# C1_G       -2.597400e+00 -2.597400e+00 -2.597400e+00 -2.597400e+00
# C3_G        1.332000e+00  1.332000e+00  1.332000e+00  1.332000e+00
# C2_I        3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# C1_I       -2.590000e+00 -2.590000e+00 -2.590000e+00 -2.590000e+00
# C3_I        1.332000e+00  1.332000e+00  1.332000e+00  1.332000e+00
# C2_M        3.700000e-01  3.700000e-01  3.700000e-01  3.700000e-01
# C1_M       -1.570000e+00 -1.570000e+00 -1.570000e+00 -1.570000e+00
# C3_M        5.092900e+00  5.092900e+00  5.092900e+00  5.092900e+00
# M_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_FITTED    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# GDE         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_FITTED  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_A         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_FITTED    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_A         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_D       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_X       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_A       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# M_FITTED    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# M_A         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# M_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# index               2015
# Y           1.862357e+06
# CPV         1.476067e+06
# I           5.364167e+05
# G           1.544669e+05
# X           1.992149e+05
# M           6.927948e+05
# YDISC       1.889869e+05
# C2_CPV      3.800000e-01
# C1_CPV     -1.100000e-01
# C3_CPV      2.946000e-02
# C2_G        3.000000e-01
# C1_G       -2.597400e+00
# C3_G        1.332000e+00
# C2_I        3.000000e-01
# C1_I       -2.590000e+00
# C3_I        1.332000e+00
# C2_M        3.700000e-01
# C1_M       -1.570000e+00
# C3_M        5.092900e+00
# M_X         0.000000e+00
# I_X         0.000000e+00
# G_D         0.000000e+00
# I_D         0.000000e+00
# I_FITTED    0.000000e+00
# GDE         0.000000e+00
# CPV_FITTED  0.000000e+00
# G_A         0.000000e+00
# G_FITTED    0.000000e+00
# G_X         0.000000e+00
# I_A         0.000000e+00
# CPV_D       0.000000e+00
# CPV_X       0.000000e+00
# CPV_A       0.000000e+00
# M_FITTED    0.000000e+00
# M_A         0.000000e+00
# M_D         0.000000e+00

# %% [markdown]
# ### Generate the variables defined by identities in the specification.
# A model which can calculate the identities can be extracted from the model instance by ```.get_histmodel()```.
#
# This small model is run for all years.

# %%
hist_smallmodel = msmallmodel.get_histmodel()

# %%
print(hist_smallmodel.equations)
# Out:
# FRML <IDENT> Y = CPV+I+G+X-M+YDISC$
# FRML <IDENT> GDE = CPV+I+G$

# %%
baseline = hist_smallmodel(baseline_first,silent=1)

# %%
baseline.head().T
# Out:
# index               2011          2012          2013          2014  \
# Y           1.562682e+06  1.632041e+06  1.689573e+06  1.791140e+06
# CPV         1.320302e+06  1.360376e+06  1.396402e+06  1.438904e+06
# I           3.739388e+05  3.811702e+05  4.145568e+05  4.664730e+05
# G           1.312720e+05  1.288601e+05  1.242549e+05  1.385327e+05
# X           1.217150e+05  1.462929e+05  1.652346e+05  1.947055e+05
# M           4.442322e+05  4.577457e+05  5.224477e+05  6.322079e+05
# YDISC       5.968622e+04  7.308714e+04  1.115720e+05  1.847331e+05
# C2_CPV      3.800000e-01  3.800000e-01  3.800000e-01  3.800000e-01
# C1_CPV     -1.100000e-01 -1.100000e-01 -1.100000e-01 -1.100000e-01
# C3_CPV      2.946000e-02  2.946000e-02  2.946000e-02  2.946000e-02
# C2_G        3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# C1_G       -2.597400e+00 -2.597400e+00 -2.597400e+00 -2.597400e+00
# C3_G        1.332000e+00  1.332000e+00  1.332000e+00  1.332000e+00
# C2_I        3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# C1_I       -2.590000e+00 -2.590000e+00 -2.590000e+00 -2.590000e+00
# C3_I        1.332000e+00  1.332000e+00  1.332000e+00  1.332000e+00
# C2_M        3.700000e-01  3.700000e-01  3.700000e-01  3.700000e-01
# C1_M       -1.570000e+00 -1.570000e+00 -1.570000e+00 -1.570000e+00
# C3_M        5.092900e+00  5.092900e+00  5.092900e+00  5.092900e+00
# M_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_FITTED    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# GDE         1.825513e+06  1.870406e+06  1.935214e+06  2.043910e+06
# CPV_FITTED  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_A         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_FITTED    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_A         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_D       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_X       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_A       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# M_FITTED    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# M_A         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# M_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# index               2015
# Y           1.862358e+06
# CPV         1.476067e+06
# I           5.364167e+05
# G           1.544669e+05
# X           1.992149e+05
# M           6.927948e+05
# YDISC       1.889869e+05
# C2_CPV      3.800000e-01
# C1_CPV     -1.100000e-01
# C3_CPV      2.946000e-02
# C2_G        3.000000e-01
# C1_G       -2.597400e+00
# C3_G        1.332000e+00
# C2_I        3.000000e-01
# C1_I       -2.590000e+00
# C3_I        1.332000e+00
# C2_M        3.700000e-01
# C1_M       -1.570000e+00
# C3_M        5.092900e+00
# M_X         0.000000e+00
# I_X         0.000000e+00
# G_D         0.000000e+00
# I_D         0.000000e+00
# I_FITTED    0.000000e+00
# GDE         2.166951e+06
# CPV_FITTED  0.000000e+00
# G_A         0.000000e+00
# G_FITTED    0.000000e+00
# G_X         0.000000e+00
# I_A         0.000000e+00
# CPV_D       0.000000e+00
# CPV_X       0.000000e+00
# CPV_A       0.000000e+00
# M_FITTED    0.000000e+00
# M_A         0.000000e+00
# M_D         0.000000e+00

# %% [markdown]
# ### Generate the add factors which will ensure that the model result match the data
# The model is named ```.calc_add_factor_model()``` and run for the relevant years:
#
# In addition if a model to create fitted values is present it will also be run.

# %%
fitbaseline = msmallmodel.calc_add_factor_model(baseline,'2016','2030')
if thismodel.mfitmodel : fitbaseline = thismodel.mfitmodel(fitbaseline)
# Out:
# Will start calculating: Calculate add factors
# 2016  solved
# 2017  solved
# 2018  solved
# 2019  solved
# 2020  solved
# 2021  solved
# 2022  solved
# 2023  solved
# 2024  solved
# 2025  solved
# 2026  solved
# 2027  solved
# 2028  solved
# 2029  solved
# 2030  solved
# Calculate add factors calculated
# Will start calculating: Small demo model calc fittet values
# 2012  solved
# 2013  solved
# 2014  solved
# 2015  solved
# 2016  solved
# 2017  solved
# 2018  solved
# 2019  solved
# 2020  solved
# 2021  solved
# 2022  solved
# 2023  solved
# 2024  solved
# 2025  solved
# 2026  solved
# 2027  solved
# 2028  solved
# 2029  solved
# 2030  solved
# Small demo model calc fittet values calculated

# %%
fitbaseline.loc['2014':'2020',].T
# Out:
# index               2014          2015          2016          2017  \
# Y           1.791140e+06  1.862358e+06  1.870423e+06  2.038336e+06
# CPV         1.438904e+06  1.476067e+06  1.537410e+06  1.549515e+06
# I           4.664730e+05  5.364167e+05  5.706795e+05  7.024075e+05
# G           1.385327e+05  1.544669e+05  1.359905e+05  1.651193e+05
# X           1.947055e+05  1.992149e+05  1.647389e+05  1.793270e+05
# M           6.322079e+05  6.927948e+05  7.146256e+05  9.164699e+05
# YDISC       1.847331e+05  1.889869e+05  1.762300e+05  3.584375e+05
# C2_CPV      3.800000e-01  3.800000e-01  3.800000e-01  3.800000e-01
# C1_CPV     -1.100000e-01 -1.100000e-01 -1.100000e-01 -1.100000e-01
# C3_CPV      2.946000e-02  2.946000e-02  2.946000e-02  2.946000e-02
# C2_G        3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# C1_G       -2.597400e+00 -2.597400e+00 -2.597400e+00 -2.597400e+00
# C3_G        1.332000e+00  1.332000e+00  1.332000e+00  1.332000e+00
# C2_I        3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# C1_I       -2.590000e+00 -2.590000e+00 -2.590000e+00 -2.590000e+00
# C3_I        1.332000e+00  1.332000e+00  1.332000e+00  1.332000e+00
# C2_M        3.700000e-01  3.700000e-01  3.700000e-01  3.700000e-01
# C1_M       -1.570000e+00 -1.570000e+00 -1.570000e+00 -1.570000e+00
# C3_M        5.092900e+00  5.092900e+00  5.092900e+00  5.092900e+00
# M_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# G_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_FITTED    3.069111e+05  3.301703e+05  3.511096e+05  4.106828e+05
# GDE         2.043910e+06  2.166951e+06  2.244080e+06  2.417042e+06
# CPV_FITTED  1.442298e+06  1.501462e+06  1.546577e+06  1.592550e+06
# G_A         0.000000e+00  0.000000e+00 -1.008167e-01  7.239171e-02
# G_FITTED    1.348067e+05  1.442680e+05  1.504155e+05  1.535884e+05
# G_X         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# I_A         0.000000e+00  0.000000e+00  4.857292e-01  5.366926e-01
# CPV_D       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_X       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CPV_A       0.000000e+00  0.000000e+00 -5.944844e-03 -2.739478e-02
# M_FITTED    6.266769e+05  7.352346e+05  7.061892e+05  8.910391e+05
# M_A         0.000000e+00  0.000000e+00  1.187554e-02  2.814086e-02
# M_D         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# index               2018          2019          2020
# Y           2.193707e+06  2.339742e+06  2.295808e+06
# CPV         1.645118e+06  1.737872e+06  1.802824e+06
# I           7.853714e+05  8.744805e+05  8.439611e+05
# G           1.685068e+05  1.808724e+05  1.920108e+05
# X           1.931247e+05  2.038306e+05  1.712825e+05
# M           1.090956e+06  1.154398e+06  9.780649e+05
# YDISC       4.925420e+05  4.970841e+05  2.637941e+05
# C2_CPV      3.800000e-01  3.800000e-01  3.800000e-01
# C1_CPV     -1.100000e-01 -1.100000e-01 -1.100000e-01
# C3_CPV      2.946000e-02  2.946000e-02  2.946000e-02
# C2_G        3.000000e-01  3.000000e-01  3.000000e-01
# C1_G       -2.597400e+00 -2.597400e+00 -2.597400e+00
# C3_G        1.332000e+00  1.332000e+00  1.332000e+00
# C2_I        3.000000e-01  3.000000e-01  3.000000e-01
# C1_I       -2.590000e+00 -2.590000e+00 -2.590000e+00
# C3_I        1.332000e+00  1.332000e+00  1.332000e+00
# C2_M        3.700000e-01  3.700000e-01  3.700000e-01
# C1_M       -1.570000e+00 -1.570000e+00 -1.570000e+00
# C3_M        5.092900e+00  5.092900e+00  5.092900e+00
# M_X         0.000000e+00  0.000000e+00  0.000000e+00
# I_X         0.000000e+00  0.000000e+00  0.000000e+00
# G_D         0.000000e+00  0.000000e+00  0.000000e+00
# I_D         0.000000e+00  0.000000e+00  0.000000e+00
# I_FITTED    4.780094e+05  5.227907e+05  5.141391e+05
# GDE         2.598996e+06  2.793225e+06  2.838796e+06
# CPV_FITTED  1.652847e+06  1.763442e+06  1.865086e+06
# G_A        -5.228553e-02 -5.720258e-03  9.622777e-02
# G_FITTED    1.775517e+05  1.819100e+05  1.743952e+05
# G_X         0.000000e+00  0.000000e+00  0.000000e+00
# I_A         4.965263e-01  5.144488e-01  4.956126e-01
# CPV_D       0.000000e+00  0.000000e+00  0.000000e+00
# CPV_X       0.000000e+00  0.000000e+00  0.000000e+00
# CPV_A      -4.686922e-03 -1.460601e-02 -3.395268e-02
# M_FITTED    1.062194e+06  1.214574e+06  9.724242e+05
# M_A         2.671811e-02 -5.081463e-02  5.783861e-03
# M_D         0.000000e+00  0.000000e+00  0.000000e+00

# %%
result = msmallmodel(fitbaseline,'2020','2030',silent=1,solver='sim')
msmallmodel.basedf = fitbaseline

# %%
msmallmodel['#endo']
# Out:
# Tab(children=(Tab(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg …

# %% [markdown]
# ## Dump the model and the data in a file to be used in the next episode

# %%
msmallmodel.modeldump('models/smallmodel.pcim')
