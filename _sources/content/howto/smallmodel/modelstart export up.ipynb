# %% [markdown]
# # Experiment: Export up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
from modelclass import model
model.widescreen()
# Out:
#         <style>
#             div#notebook-container    { width: 95%; }
#             div#menubar-container     { width: 65%; }
#             div#maintoolbar-container { width: 99%; }
#         </style>

# %% [markdown]
# ## Load the precooked model
# This model was generated from scratch [here](modelstart.ipynb)

# %%
msmallmodel,baseline = model.modelload('models/smallmodel.pcim',run=1,keep='Baseline',silent=1,alfa=0.5)

# %% [markdown]
# ## Create new dataframe where the export is increased by 10 percent

# %%
impuls_x_10pct = baseline.upd("<2024 2027> x % 10")

# %% [markdown]
# ## Simulate the model

# %%
result_x = msmallmodel(impuls_x_10pct,silent=1,alfa=0.5,keep='Export increased by 10 percent')

# %% [markdown]
# ## Display results

# %%
with msmallmodel.set_smpl('2020','2030'):
    display(msmallmodel['y cpv g x m gde' ])
# Out:
# Tab(children=(Tab(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg …

# %%
msmallmodel['y cpv g  m gde'].difpctlevel.rename().mul100.plot(sharey=True);

# %%
try:
    msmallmodel.modeldash('Y',jupyter=1,inline=1)
except Exception as e:
    print(f"Can't run modeldash here")
# Out:
# apprun
# C:\Users\ibhan\Anaconda3\lib\site-packages\jupyter_dash\jupyter_app.py:139: UserWarning: The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.
#   func()
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5001/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
