# %%
# %matplotlib notebook

# %% [markdown]
# # Create an experiment, simulate it and access results
#
# This notebook shows how to make a single simple experiment
#
# 1. Loading a pre-existing model in Modelflow
# 2. Create an experimet by updating some variables
# 3. Simulate the model
# 4. Visualizing the results
#
# This Notebook uses a  model for Pakistan described here: {cite:author}`Burns2021`

# %% [markdown]
# ## Imports
#
# Modelflow's modelclass includes most of the methods needed to manage a model in Modelflow.

# %%
from modelclass import model 
model.widescreen()
model.scroll_off()
# Out:
#         <style>
#             div#notebook-container    { width: 95%; }
#             div#menubar-container     { width: 65%; }
#             div#maintoolbar-container { width: 99%; }
#         </style>

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load a pre-existing model, data and descriptions
# The file `pak.pcim` contains a dump of model equations, dataframe, simulation options and variable descriptions.

# %%
mpak,baseline = model.modelload('../../models/pak.pcim',alfa=0.7,run=1)

# %% [markdown]
# ## Create an experiments
# The variable ```mpak``` contains the model instance and the variable   ```baseline```contains the pandas dataframe with all series.
#
# We want to make an experiment where these variables: PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER are updated
#
# The the variables contains tax rates for CO2 emission from different sources. The descriptions can be retrieved like this:

# %% [markdown]
# :::{margin} **Variable descriptions**
# Are contained in the variable '''mpak.var_description'''
# which is a dictionary
# :::

# %%
for variable in ['PAKGGREVCO2CER', 'PAKGGREVCO2GER', 'PAKGGREVCO2OER']:
    print(variable,':',mpak.var_description[variable])
# Out:
# PAKGGREVCO2CER : Tax/subsidy (Coal) (USD p/tco2)
# PAKGGREVCO2GER : Tax/subsidy (Gas) (USD p/tco2)
# PAKGGREVCO2OER : Tax/subsidy (Oil) (USD p/tco2)

# %% [markdown]
# In order to update series in a pandas dataframe, one can use the pandas functions. However modelflow contains
# some functions which has been designed to make updating economic series parsimonious and effective. So here the function: ```model.update``` is used.
#
# ```dataframe.upd``` creates a new dataframe where the tree tax variables are updated. You will find more [here](./model%20update.ipynb)

# %%
alternative  =  baseline.upd("<2020 2100> PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER = 29")

# %% [markdown]
# ## Run the model with all the scenarios

# %%
result = mpak(alternative,2020,2100) # simulates the model

# %% [markdown]
# ## Access results
#
# Now we have two dataframes with results ```baseline```and ```result```. These dataframes can be manipulated and visualized
# with the tools provided by the **pandas** library and other like **Matplotlib* and **Plotly**. However to make things easy the first and
# latest simulation result is also in the mpak object:
#
# - **mpak.basedf**: Dataframe with the values for baseline
# - **mpak.lastdf**: Dataframe with the values for alternative

# %% [markdown]
# ### An overview of GDP

# %%
with mpak.set_smpl(2020,2023):   # set smpl in the indented block
    mpak.PAKNYGDPMKTPKN.show
# Out:
# Endogeneous: PAKNYGDPMKTPKN: GDP Expenditure side at market prices
# Formular: FRML  <> PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN-PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $
#
# PAKNYGDPMKTPKN: GDP Expenditure side at market prices
# PAKADAP       : Switch on adaptation mode (0 or 1)
# PAKDISPREPKN  : Investment in disaster risk preparation, constant prices
# PAKNECONGOVTKN: Government Consumption
# PAKNECONPRVTKN: Household Consumption
# PAKNEEXPGNFSKN: Exports (G&S)
# PAKNEGDIFTOTKN: Total Gross Capital Formation
# PAKNEGDISTKBKN: Change in Inventories
# PAKNEIMPGNFSKN: Imports (G&S)
# PAKNYGDPDISCKN: Statistical Discrepency (Expenditure Side)
#
# Values :
# <style type="text/css">
# #T_28b59 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_28b59 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_28b59 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_28b59 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_28b59 #T_28b59_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row0_col0 .pd-t::after {
#   content: "2020";
# }
# #T_28b59 #T_28b59_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row0_col1 .pd-t::after {
#   content: "2021";
# }
# #T_28b59 #T_28b59_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row0_col2 .pd-t::after {
#   content: "2022";
# }
# #T_28b59 #T_28b59_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row0_col3 .pd-t::after {
#   content: "2023";
# }
# #T_28b59 #T_28b59_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row1_col0 .pd-t::after {
#   content: "2020";
# }
# #T_28b59 #T_28b59_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row1_col1 .pd-t::after {
#   content: "2021";
# }
# #T_28b59 #T_28b59_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row1_col2 .pd-t::after {
#   content: "2022";
# }
# #T_28b59 #T_28b59_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row1_col3 .pd-t::after {
#   content: "2023";
# }
# #T_28b59 #T_28b59_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row2_col0 .pd-t::after {
#   content: "2020";
# }
# #T_28b59 #T_28b59_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row2_col1 .pd-t::after {
#   content: "2021";
# }
# #T_28b59 #T_28b59_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row2_col2 .pd-t::after {
#   content: "2022";
# }
# #T_28b59 #T_28b59_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_28b59 #T_28b59_row2_col3 .pd-t::after {
#   content: "2023";
# }
# </style>
# <table id="T_28b59" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28b59_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_28b59_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_28b59_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_28b59_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28b59_level0_row0" class="row_heading level0 row0" >Base</th>
#       <td id="T_28b59_row0_col0" class="data row0 col0" >26,701,602.43<span class="pd-t"></span></td>
#       <td id="T_28b59_row0_col1" class="data row0 col1" >27,202,580.71<span class="pd-t"></span></td>
#       <td id="T_28b59_row0_col2" class="data row0 col2" >27,801,259.41<span class="pd-t"></span></td>
#       <td id="T_28b59_row0_col3" class="data row0 col3" >28,499,818.71<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_28b59_level0_row1" class="row_heading level0 row1" >Last</th>
#       <td id="T_28b59_row1_col0" class="data row1 col0" >26,483,175.56<span class="pd-t"></span></td>
#       <td id="T_28b59_row1_col1" class="data row1 col1" >27,235,594.38<span class="pd-t"></span></td>
#       <td id="T_28b59_row1_col2" class="data row1 col2" >27,963,320.84<span class="pd-t"></span></td>
#       <td id="T_28b59_row1_col3" class="data row1 col3" >28,690,715.60<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_28b59_level0_row2" class="row_heading level0 row2" >Diff</th>
#       <td id="T_28b59_row2_col0" class="data row2 col0" >-218,426.87<span class="pd-t"></span></td>
#       <td id="T_28b59_row2_col1" class="data row2 col1" >33,013.67<span class="pd-t"></span></td>
#       <td id="T_28b59_row2_col2" class="data row2 col2" >162,061.44<span class="pd-t"></span></td>
#       <td id="T_28b59_row2_col3" class="data row2 col3" >190,896.89<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>
# Input last run:
# <style type="text/css">
# #T_b0139 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_b0139 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_b0139 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_b0139 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_b0139 #T_b0139_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row0_col0 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_b0139 #T_b0139_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row0_col1 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_b0139 #T_b0139_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row0_col2 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_b0139 #T_b0139_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row0_col3 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_b0139 #T_b0139_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row1_col0 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_b0139 #T_b0139_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row1_col1 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_b0139 #T_b0139_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row1_col2 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_b0139 #T_b0139_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row1_col3 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_b0139 #T_b0139_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row2_col0 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_b0139 #T_b0139_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row2_col1 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_b0139 #T_b0139_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row2_col2 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_b0139 #T_b0139_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row2_col3 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_b0139 #T_b0139_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row3_col0 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_b0139 #T_b0139_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row3_col1 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_b0139 #T_b0139_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row3_col2 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_b0139 #T_b0139_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row3_col3 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_b0139 #T_b0139_row4_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row4_col0 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_b0139 #T_b0139_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row4_col1 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_b0139 #T_b0139_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row4_col2 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_b0139 #T_b0139_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row4_col3 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_b0139 #T_b0139_row5_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row5_col0 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_b0139 #T_b0139_row5_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row5_col1 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_b0139 #T_b0139_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row5_col2 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_b0139 #T_b0139_row5_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row5_col3 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_b0139 #T_b0139_row6_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row6_col0 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_b0139 #T_b0139_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row6_col1 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_b0139 #T_b0139_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row6_col2 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_b0139 #T_b0139_row6_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row6_col3 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_b0139 #T_b0139_row7_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row7_col0 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_b0139 #T_b0139_row7_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row7_col1 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_b0139 #T_b0139_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row7_col2 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_b0139 #T_b0139_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row7_col3 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_b0139 #T_b0139_row8_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row8_col0 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_b0139 #T_b0139_row8_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row8_col1 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_b0139 #T_b0139_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row8_col2 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_b0139 #T_b0139_row8_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b0139 #T_b0139_row8_col3 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# </style>
# <table id="T_b0139" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0139_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_b0139_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_b0139_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_b0139_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0139_level0_row0" class="row_heading level0 row0" >PAKADAP</th>
#       <td id="T_b0139_row0_col0" class="data row0 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_b0139_row0_col1" class="data row0 col1" >0.00<span class="pd-t"></span></td>
#       <td id="T_b0139_row0_col2" class="data row0 col2" >0.00<span class="pd-t"></span></td>
#       <td id="T_b0139_row0_col3" class="data row0 col3" >0.00<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_b0139_level0_row1" class="row_heading level0 row1" >PAKDISPREPKN</th>
#       <td id="T_b0139_row1_col0" class="data row1 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_b0139_row1_col1" class="data row1 col1" >0.00<span class="pd-t"></span></td>
#       <td id="T_b0139_row1_col2" class="data row1 col2" >0.00<span class="pd-t"></span></td>
#       <td id="T_b0139_row1_col3" class="data row1 col3" >0.00<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_b0139_level0_row2" class="row_heading level0 row2" >PAKNECONGOVTKN</th>
#       <td id="T_b0139_row2_col0" class="data row2 col0" >3,247,354.35<span class="pd-t"></span></td>
#       <td id="T_b0139_row2_col1" class="data row2 col1" >3,345,916.18<span class="pd-t"></span></td>
#       <td id="T_b0139_row2_col2" class="data row2 col2" >3,416,029.38<span class="pd-t"></span></td>
#       <td id="T_b0
# Input base run:
# <style type="text/css">
# #T_2bc36 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_2bc36 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_2bc36 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_2bc36 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_2bc36 #T_2bc36_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row0_col0 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_2bc36 #T_2bc36_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row0_col1 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_2bc36 #T_2bc36_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row0_col2 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_2bc36 #T_2bc36_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row0_col3 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_2bc36 #T_2bc36_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row1_col0 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_2bc36 #T_2bc36_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row1_col1 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_2bc36 #T_2bc36_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row1_col2 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_2bc36 #T_2bc36_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row1_col3 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_2bc36 #T_2bc36_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row2_col0 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_2bc36 #T_2bc36_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row2_col1 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_2bc36 #T_2bc36_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row2_col2 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_2bc36 #T_2bc36_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row2_col3 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_2bc36 #T_2bc36_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row3_col0 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_2bc36 #T_2bc36_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row3_col1 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_2bc36 #T_2bc36_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row3_col2 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_2bc36 #T_2bc36_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row3_col3 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_2bc36 #T_2bc36_row4_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row4_col0 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_2bc36 #T_2bc36_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row4_col1 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_2bc36 #T_2bc36_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row4_col2 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_2bc36 #T_2bc36_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row4_col3 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_2bc36 #T_2bc36_row5_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row5_col0 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_2bc36 #T_2bc36_row5_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row5_col1 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_2bc36 #T_2bc36_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row5_col2 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_2bc36 #T_2bc36_row5_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row5_col3 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_2bc36 #T_2bc36_row6_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row6_col0 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_2bc36 #T_2bc36_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row6_col1 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_2bc36 #T_2bc36_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row6_col2 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_2bc36 #T_2bc36_row6_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row6_col3 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_2bc36 #T_2bc36_row7_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row7_col0 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_2bc36 #T_2bc36_row7_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row7_col1 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_2bc36 #T_2bc36_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row7_col2 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_2bc36 #T_2bc36_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row7_col3 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_2bc36 #T_2bc36_row8_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row8_col0 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_2bc36 #T_2bc36_row8_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row8_col1 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_2bc36 #T_2bc36_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row8_col2 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_2bc36 #T_2bc36_row8_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_2bc36 #T_2bc36_row8_col3 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# </style>
# <table id="T_2bc36" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bc36_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_2bc36_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_2bc36_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_2bc36_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc36_level0_row0" class="row_heading level0 row0" >PAKADAP</th>
#       <td id="T_2bc36_row0_col0" class="data row0 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_2bc36_row0_col1" class="data row0 col1" >0.00<span class="pd-t"></span></td>
#       <td id="T_2bc36_row0_col2" class="data row0 col2" >0.00<span class="pd-t"></span></td>
#       <td id="T_2bc36_row0_col3" class="data row0 col3" >0.00<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_2bc36_level0_row1" class="row_heading level0 row1" >PAKDISPREPKN</th>
#       <td id="T_2bc36_row1_col0" class="data row1 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_2bc36_row1_col1" class="data row1 col1" >0.00<span class="pd-t"></span></td>
#       <td id="T_2bc36_row1_col2" class="data row1 col2" >0.00<span class="pd-t"></span></td>
#       <td id="T_2bc36_row1_col3" class="data row1 col3" >0.00<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_2bc36_level0_row2" class="row_heading level0 row2" >PAKNECONGOVTKN</th>
#       <td id="T_2bc36_row2_col0" class="data row2 col0" >3,011,416.67<span class="pd-t"></span></td>
#       <td id="T_2bc36_row2_col1" class="data row2 col1" >3,070,297.63<span class="pd-t"></span></td>
#       <td id="T_2bc36_row2_col2" class="data row2 col2" >3,147,900.67<span class="pd-t"></span></td>
#       <td id="T_2b
# Difference for input variables
# <style type="text/css">
# #T_3ce48 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_3ce48 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_3ce48 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_3ce48 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_3ce48 #T_3ce48_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row0_col0 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_3ce48 #T_3ce48_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row0_col1 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_3ce48 #T_3ce48_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row0_col2 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_3ce48 #T_3ce48_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row0_col3 .pd-t::after {
#   content: "Switch on adaptation mode (0 or 1)";
# }
# #T_3ce48 #T_3ce48_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row1_col0 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_3ce48 #T_3ce48_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row1_col1 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_3ce48 #T_3ce48_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row1_col2 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_3ce48 #T_3ce48_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row1_col3 .pd-t::after {
#   content: "Investment in disaster risk preparation, constant prices";
# }
# #T_3ce48 #T_3ce48_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row2_col0 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_3ce48 #T_3ce48_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row2_col1 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_3ce48 #T_3ce48_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row2_col2 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_3ce48 #T_3ce48_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row2_col3 .pd-t::after {
#   content: "Government Consumption";
# }
# #T_3ce48 #T_3ce48_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row3_col0 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_3ce48 #T_3ce48_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row3_col1 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_3ce48 #T_3ce48_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row3_col2 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_3ce48 #T_3ce48_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row3_col3 .pd-t::after {
#   content: "Household Consumption";
# }
# #T_3ce48 #T_3ce48_row4_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row4_col0 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_3ce48 #T_3ce48_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row4_col1 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_3ce48 #T_3ce48_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row4_col2 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_3ce48 #T_3ce48_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row4_col3 .pd-t::after {
#   content: "Exports (G&S)";
# }
# #T_3ce48 #T_3ce48_row5_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row5_col0 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_3ce48 #T_3ce48_row5_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row5_col1 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_3ce48 #T_3ce48_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row5_col2 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_3ce48 #T_3ce48_row5_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row5_col3 .pd-t::after {
#   content: "Total Gross Capital Formation";
# }
# #T_3ce48 #T_3ce48_row6_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row6_col0 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_3ce48 #T_3ce48_row6_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row6_col1 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_3ce48 #T_3ce48_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row6_col2 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_3ce48 #T_3ce48_row6_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row6_col3 .pd-t::after {
#   content: "Change in Inventories";
# }
# #T_3ce48 #T_3ce48_row7_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row7_col0 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_3ce48 #T_3ce48_row7_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row7_col1 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_3ce48 #T_3ce48_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row7_col2 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_3ce48 #T_3ce48_row7_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row7_col3 .pd-t::after {
#   content: "Imports (G&S)";
# }
# #T_3ce48 #T_3ce48_row8_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row8_col0 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_3ce48 #T_3ce48_row8_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row8_col1 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_3ce48 #T_3ce48_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row8_col2 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# #T_3ce48 #T_3ce48_row8_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_3ce48 #T_3ce48_row8_col3 .pd-t::after {
#   content: "Statistical Discrepency (Expenditure Side)";
# }
# </style>
# <table id="T_3ce48" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ce48_level0_col0" class="col_heading level0 col0" >2020</th>
#       <th id="T_3ce48_level0_col1" class="col_heading level0 col1" >2021</th>
#       <th id="T_3ce48_level0_col2" class="col_heading level0 col2" >2022</th>
#       <th id="T_3ce48_level0_col3" class="col_heading level0 col3" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ce48_level0_row0" class="row_heading level0 row0" >PAKADAP</th>
#       <td id="T_3ce48_row0_col0" class="data row0 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_3ce48_row0_col1" class="data row0 col1" >0.00<span class="pd-t"></span></td>
#       <td id="T_3ce48_row0_col2" class="data row0 col2" >0.00<span class="pd-t"></span></td>
#       <td id="T_3ce48_row0_col3" class="data row0 col3" >0.00<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_3ce48_level0_row1" class="row_heading level0 row1" >PAKDISPREPKN</th>
#       <td id="T_3ce48_row1_col0" class="data row1 col0" >0.00<span class="pd-t"></span></td>
#       <td id="T_3ce48_row1_col1" class="data row1 col1" >0.00<span class="pd-t"></span></td>
#       <td id="T_3ce48_row1_col2" class="data row1 col2" >0.00<span class="pd-t"></span></td>
#       <td id="T_3ce48_row1_col3" class="data row1 col3" >0.00<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_3ce48_level0_row2" class="row_heading level0 row2" >PAKNECONGOVTKN</th>
#       <td id="T_3ce48_row2_col0" class="data row2 col0" >235,937.67<span class="pd-t"></span></td>
#       <td id="T_3ce48_row2_col1" class="data row2 col1" >275,618.54<span class="pd-t"></span></td>
#       <td id="T_3ce48_row2_col2" class="data row2 col2" >268,128.71<span class="pd-t"></span></td>
#       <td id="T_3ce48_ro

# %% [markdown]
# ### look at selected variables with the [] operator
# If you want to look at multiple variables the index [] operator can be used to select the variables to analyze/visualize. Here only a few operations will be shown. There is more [here](index-operator)

# %%
mpak['PAKNECONGOVTKN PAKNEGDIFTOTKN PAKNEIMPGNFSKN']
# Out:
# Tab(children=(Tab(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg …
